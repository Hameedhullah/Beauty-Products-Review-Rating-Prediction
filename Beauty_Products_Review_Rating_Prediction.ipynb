# %% [markdown]
# <a href="https://colab.research.google.com/github/Hameedhullah/Beauty-Products-Review-Rating-Prediction/blob/main/Beauty_Products_Review_Rating_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot  as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
data_train = pd.read_csv('Train.csv')

# %%
data_train.head()
# Out:
#    rating                                title  \
# 0       5                 Unique and authentic
# 1       2                        Uncomfortable
# 2       3  Something has changed for the worse
# 3       5                           Five Stars
# 4       3                          1/4 and 3/4
#
#                                                 text        asin parent_asin  \
# 0  A very classy and chic look. This necklace is ...  B0107QYW14  B0107QYW14
# 1  The cloth bands tend to scrunch up under my wi...  B08WX159BW  B08WX159BW
# 2  Really loved this product the first time I bou...  B083F76L79  B083F76L79
# 3                                          beautiful  B00FBXJ11K  B00FBXJ11K
# 4  I was so excited to get these.  I opened the b...  B00F029PWC  B00F029PWC
#
#       timestamp  helpful_vote  verified_purchase
# 0  1.460000e+12             2               True
# 1  1.630000e+12             0               True
# 2  1.630000e+12             1               True
# ...

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39986 entries, 0 to 39985
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rating             39986 non-null  int64
#  1   title              39986 non-null  object
#  2   text               39986 non-null  object
#  3   asin               39986 non-null  object
#  4   parent_asin        39986 non-null  object
#  5   timestamp          39986 non-null  float64
#  6   helpful_vote       39986 non-null  int64
#  7   verified_purchase  39986 non-null  bool
# dtypes: bool(1), float64(1), int64(2), object(4)
# memory usage: 2.2+ MB

# %%
# Null Values

data_train.isna().sum()
# Out:
# rating               0
# title                0
# text                 0
# asin                 0
# parent_asin          0
# timestamp            0
# helpful_vote         0
# verified_purchase    0
# dtype: int64

# %%
# Duplicated Values

dup_data = data_train.loc[data_train.duplicated(keep='last')]

# %%
dup_data
# Out:
#        rating                           title  \
# 40          1  Lots of dye and very per-fumy.
# 98          5             Beautiful and plus!
# 172         5      Great material, well made.
# 715         1           Help think it is bad!
# 818         5                           Great
# ...       ...                             ...
# 24796       5               Very nice bottle.
# 29218       5                       Excellent
# 35107       5           Best I’ve ever found!
# 35742       4                            Nice
# 38404       4                      Four Stars
#
#                                                     text        asin  \
# 40     Very full of dye and perfume. Overpowering and...  B07NHNLJ4T
# 98     Exactly what I was looking for and in a very b...  B086ST4W1C
# 172    This is a well made product. The band is wide ...  B07LB3V58G
# 715    Wondering if I could get a replacement as this...  B00O965C0O
# ...

# %%
data_train.drop_duplicates(inplace=True)

# %%
data_train.shape
# Out:
# (39910, 8)

# %%
data_train.describe()
# Out:
#              rating     timestamp  helpful_vote
# count  39910.000000  3.991000e+04  39910.000000
# mean       4.068529  1.551985e+12      0.937810
# std        1.377391  7.764327e+10      4.679911
# min        1.000000  1.040000e+12      0.000000
# 25%        3.000000  1.500000e+12      0.000000
# 50%        5.000000  1.570000e+12      0.000000
# 75%        5.000000  1.610000e+12      1.000000
# max        5.000000  1.680000e+12    430.000000

# %%
data_train.describe(include='O')
# Out:
#              title     text        asin parent_asin
# count        39910    39910       39910       39910
# unique       27511    38326       21555       21031
# top     Five Stars  Love it  B007IAE5WY  B085BB7B1M
# freq          2404       81         139         139

# %%
print("Unique values in columns")
data_train.nunique().sort_values()
# Out:
# Unique values in columns
# verified_purchase        2
# rating                   5
# timestamp               63
# helpful_vote            84
# parent_asin          21031
# asin                 21555
# title                27511
# text                 38326
# dtype: int64

# %%
for i in data_train.columns:
  print(f"Unique value in {i}")
  print(data_train[i].unique(), '\n')
# Out:
# Unique value in rating
# [5 2 3 4 1]
#
# Unique value in title
# ['Unique and authentic' 'Uncomfortable'
#  'Something has changed for the worse' ... '*****5-STARS PLUS*****'
#  'A fine shaver' 'Didnt work']
#
# Unique value in text
# ['A very classy and chic look. This necklace is  well made and feels light weight on you. It does not feel heavy or pull down around your neck. The stone looks like real turquoise. It looks authentic and even expensive. It can be worn with just about anything and it looks great.'
#  'The cloth bands tend to scrunch up under my wigs, so thought this would be more stable. Sticks so much to skin and hair, it is hard to slide on and into place and pulls on my own hair. Was worth a try, but not for me.'
# ...

# %%
data_train.select_dtypes(include = ['int64','float64']).skew().round(4)
# Out:
# rating          -1.2474
# timestamp       -1.0014
# helpful_vote    33.3893
# dtype: float64

# %%
data_train.sample()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4d0db0a1eef7> in <cell line: 0>()
# ----> 1 data_train.sample()
#
# NameError: name 'data_train' is not defined
